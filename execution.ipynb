# %%
import slc
# Out:
# N=600, row=8, col=8
# number of iterations = 8000, cost = 0.002302, eta = 5.000000e-01
#
# number of iterations = 8000, cost = 0.001263, eta = 4.000000e-01
# in-samples error = 0.001263
# [[293.   0.]
#  [  0. 307.]]
