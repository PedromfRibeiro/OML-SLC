# %%
import slc
# Out:
# N=1500, row=12, col=12
# number of iterations = 3000, cost = 0.004307, eta = 1.000000e+00
#
# number of iterations = 3000, cost = 0.001776, eta = 5.000000e-01
# in-samples error = 0.001776
# [[612.   0.]
#  [  0. 588.]]
# out-samples error=0.001802
# [[164.   0.]
#  [  0. 136.]]
